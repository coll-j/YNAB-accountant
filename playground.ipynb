# %%
import ynab
import os
from pprint import pprint

# %%
configuration = ynab.Configuration(access_token=os.environ["YNAB_ACCESS_TOKEN"])

# %%
with ynab.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = ynab.PlansApi(api_client)
    include_accounts = True # bool | Whether to include the list of plan accounts (optional)

    try:
        # Get all plans
        api_response = api_instance.get_plans(include_accounts=include_accounts)
        print("The response of PlansApi->get_plans:\n")
        pprint(api_response)
    except Exception as e:
        print("Exception when calling PlansApi->get_plans: %s\n" % e)
# Out:
# The response of PlansApi->get_plans:
#
# PlanSummaryResponse(data=PlanSummaryResponseData(plans=[PlanSummary(id=UUID('8c90eb3f-8378-43c1-a8ed-03f56be3cb3f'), name="Yusi's Budget (Rp)", last_modified_on=datetime.datetime(2026, 5, 4, 9, 33, 33, tzinfo=TzInfo(0)), first_month=datetime.date(2024, 10, 1), last_month=datetime.date(2026, 6, 1), date_format=DateFormat(format='DD/MM/YYYY'), currency_format=CurrencyFormat(iso_code='IDR', example_format='123,456', decimal_digits=0, decimal_separator='.', symbol_first=True, group_separator=',', currency_symbol='Rp', display_symbol=True), accounts=[Account(id=UUID('555a9da9-831b-43b0-9af4-c563c466eea8'), name='Jago Yusi Jek🍀', type=<AccountType.SAVINGS: 'savings'>, on_budget=True, closed=True, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('fed36fe6-a4c9-4571-816d-81ccf72baf7f'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2025, 6, 2, 14, 56, 46, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='$0.00', balance_currency=0.0, cleared_balance_formatted='$0.00', cleared_balance_currency=0.0, uncleared_balance_formatted='$0.00', uncleared_balance_currency=0.0), Account(id=UUID('5f2ac7ce-73f5-4a89-b222-561eb0296084'), name='Mandiri Jek', type=<AccountType.CHECKING: 'checking'>, on_budget=True, closed=True, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('20962909-76c1-4511-966b-ab6be7c51436'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2025, 6, 9, 10, 56, 59, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='$0.00', balance_currency=0.0, cleared_balance_formatted='$0.00', cleared_balance_currency=0.0, uncleared_balance_formatted='$0.00', uncleared_balance_currency=0.0), Account(id=UUID('cea4f837-7cfe-4c23-a4c6-7c2c53f78008'), name='JCB CC', type=<AccountType.CREDITCARD: 'creditCard'>, on_budget=True, closed=True, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('cddfb570-7248-4359-97f0-2cf76df812a7'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2025, 10, 27, 12, 35, 4, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='$0.00', balance_currency=0.0, cleared_balance_formatted='$0.00', cleared_balance_currency=0.0, uncleared_balance_formatted='$0.00', uncleared_balance_currency=0.0), Account(id=UUID('2a080d50-801d-471d-832f-2eb5b6eaa9de'), name='Jago Subscription', type=<AccountType.CASH: 'cash'>, on_budget=True, closed=False, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('2ea4da27-1a3e-4d67-bdd6-0e7b6888e2ae'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2026, 4, 9, 13, 28, 53, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='$0.00', balance_currency=0.0, cleared_balance_formatted='$0.00', cleared_balance_currency=0.0, uncleared_balance_formatted='$0.00', uncleared_balance_currency=0.0), Account(id=UUID('a3052a3d-44ba-427e-a955-596214a09c7a'), name='Deposito Jago', type=<AccountType.OTHERASSET: 'otherAsset'>, on_budget=False, closed=False, note=None, balance=10214396000, cleared_balance=10214396000, uncleared_balance=0, transfer_payee_id=UUID('278de700-1088-4c05-9715-51e32c48cd95'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2026, 4, 9, 13, 30, 48, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='$10214396.00', balance_cu ...

# %%
# Enter a context with an instance of the API client
with ynab.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = ynab.PayeesApi(api_client)
    plan_id = os.environ["YNAB_BUDGET_ID"] # str | The id of the plan. \"last-used\" can be used to specify the last used plan and \"default\" can be used if default plan selection is enabled (see: https://api.ynab.com/#oauth-default-plan).

    try:
        # Get all payees
        api_response = api_instance.get_payees(plan_id)
        print("The response of PayeesApi->get_payees:\n")
        for payee in api_response.data.payees:
            if payee.name == "Grab Food":
                print(f"Payee ID: {payee.id}, Payee Name: {payee.name}")
    except Exception as e:
        print("Exception when calling PayeesApi->get_payees: %s\n" % e)
# Out:
# The response of PayeesApi->get_payees:
#
# Payee ID: 42340fc8-2e73-4277-b23a-1f82f2449175, Payee Name: Grab Food
