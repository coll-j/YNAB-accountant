# %%
import ynab
import os
from pprint import pprint

# %%
configuration = ynab.Configuration(access_token=os.environ["YNAB_ACCESS_TOKEN"])
api_client = ynab.ApiClient(configuration)
api_instance = ynab.PlansApi(api_client)
api_response = api_instance.get_plans(include_accounts=True)

# %%
with ynab.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = ynab.PlansApi(api_client)
    include_accounts = True # bool | Whether to include the list of plan accounts (optional)

    try:
        # Get all plans
        api_response = api_instance.get_plans(include_accounts=include_accounts)
        print("The response of PlansApi->get_plans:\n")
        pprint(api_response)
    except Exception as e:
        print("Exception when calling PlansApi->get_plans: %s\n" % e)
# Out:
# The response of PlansApi->get_plans:
#
# PlanSummaryResponse(data=PlanSummaryResponseData(plans=[PlanSummary(id=UUID('8c90eb3f-8378-43c1-a8ed-03f56be3cb3f'), name="Yusi's Budget (Rp)", last_modified_on=datetime.datetime(2026, 5, 6, 16, 28, 22, tzinfo=TzInfo(0)), first_month=datetime.date(2024, 10, 1), last_month=datetime.date(2026, 6, 1), date_format=DateFormat(format='DD/MM/YYYY'), currency_format=CurrencyFormat(iso_code='IDR', example_format='123,456', decimal_digits=0, decimal_separator='.', symbol_first=True, group_separator=',', currency_symbol='Rp', display_symbol=True), accounts=[Account(id=UUID('555a9da9-831b-43b0-9af4-c563c466eea8'), name='Jago Yusi Jek🍀', type=<AccountType.SAVINGS: 'savings'>, on_budget=True, closed=True, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('fed36fe6-a4c9-4571-816d-81ccf72baf7f'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2025, 6, 2, 14, 56, 46, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='$0.00', balance_currency=0.0, cleared_balance_formatted='$0.00', cleared_balance_currency=0.0, uncleared_balance_formatted='$0.00', uncleared_balance_currency=0.0), Account(id=UUID('5f2ac7ce-73f5-4a89-b222-561eb0296084'), name='Mandiri Jek', type=<AccountType.CHECKING: 'checking'>, on_budget=True, closed=True, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('20962909-76c1-4511-966b-ab6be7c51436'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2025, 6, 9, 10, 56, 59, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='$0.00', balance_currency=0.0, cleared_balance_formatted='$0.00', cleared_balance_currency=0.0, uncleared_balance_formatted='$0.00', uncleared_balance_currency=0.0), Account(id=UUID('cea4f837-7cfe-4c23-a4c6-7c2c53f78008'), name='JCB CC', type=<AccountType.CREDITCARD: 'creditCard'>, on_budget=True, closed=True, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('cddfb570-7248-4359-97f0-2cf76df812a7'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2025, 10, 27, 12, 35, 4, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='$0.00', balance_currency=0.0, cleared_balance_formatted='$0.00', cleared_balance_currency=0.0, uncleared_balance_formatted='$0.00', uncleared_balance_currency=0.0), Account(id=UUID('2a080d50-801d-471d-832f-2eb5b6eaa9de'), name='Jago Subscription', type=<AccountType.CASH: 'cash'>, on_budget=True, closed=False, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('2ea4da27-1a3e-4d67-bdd6-0e7b6888e2ae'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2026, 4, 9, 13, 28, 53, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='$0.00', balance_currency=0.0, cleared_balance_formatted='$0.00', cleared_balance_currency=0.0, uncleared_balance_formatted='$0.00', uncleared_balance_currency=0.0), Account(id=UUID('a3052a3d-44ba-427e-a955-596214a09c7a'), name='Deposito Jago', type=<AccountType.OTHERASSET: 'otherAsset'>, on_budget=False, closed=False, note=None, balance=10214396000, cleared_balance=10214396000, uncleared_balance=0, transfer_payee_id=UUID('278de700-1088-4c05-9715-51e32c48cd95'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2026, 4, 9, 13, 30, 48, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='$10214396.00', balance_c ...

# %%
# Enter a context with an instance of the API client
with ynab.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = ynab.PayeesApi(api_client)
    plan_id = os.environ["YNAB_BUDGET_ID"] # str | The id of the plan. \"last-used\" can be used to specify the last used plan and \"default\" can be used if default plan selection is enabled (see: https://api.ynab.com/#oauth-default-plan).

    try:
        # Get all payees
        api_response = api_instance.get_payees(plan_id)
        print("The response of PayeesApi->get_payees:\n")
        for payee in api_response.data.payees:
            if payee.name == "Food Truck":
                print(f"Payee ID: {payee.id}, Payee Name: {payee.name}")
    except Exception as e:
        print("Exception when calling PayeesApi->get_payees: %s\n" % e)
# Out:
# The response of PayeesApi->get_payees:
#
# Payee ID: 94760e7d-f213-4432-9d8e-5d014560d8b6, Payee Name: Food Truck

# %%
# Enter a context with an instance of the API client
with ynab.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = ynab.CategoriesApi(api_client)
    plan_id = os.environ["YNAB_BUDGET_ID"] # str | The id of the plan. \"last-used\" can be used to specify the last used plan and \"default\" can be used if default plan selection is enabled (see: https://api.ynab.com/#oauth-default-plan).

    try:
        # Get all categories
        api_response = api_instance.get_categories(plan_id)
        print("The response of CategoriesApi->get_categories:\n")
        pprint(api_response)
        for category_group in api_response.data.category_groups:
            for category in category_group.categories:
                if "Dining" in category.name:
                    print(f"Category ID: {category.id}, Category Name: {category.name}")
    except Exception as e:
        print("Exception when calling CategoriesApi->get_categories: %s\n" % e)
# Out:
# The response of CategoriesApi->get_categories:
#
# CategoriesResponse(data=CategoriesResponseData(category_groups=[CategoryGroupWithCategories(id=UUID('84e1c8ab-f779-4b1a-b29d-237aaefdfddc'), name='Extra Cash', hidden=True, deleted=False, categories=[Category(id=UUID('0348e5af-dc77-4571-aa51-e57b7bba33c8'), category_group_id=UUID('84e1c8ab-f779-4b1a-b29d-237aaefdfddc'), category_group_name='Extra Cash', name='Cash Yusi', hidden=True, original_category_group_id=None, note=None, budgeted=-1315000, activity=0, balance=0, goal_type=None, goal_needs_whole_amount=None, goal_day=None, goal_cadence=None, goal_cadence_frequency=None, goal_creation_month=None, goal_target=0, goal_target_month=None, goal_target_date=None, goal_percentage_complete=None, goal_months_to_budget=None, goal_under_funded=None, goal_overall_funded=None, goal_overall_left=None, goal_snoozed_at=None, deleted=False, balance_formatted='฿0', balance_currency=0, activity_formatted='฿0', activity_currency=0, budgeted_formatted='-฿1315', budgeted_currency=-1315, goal_target_formatted='฿0', goal_target_currency=0, goal_under_funded_formatted=None, goal_under_funded_currency=None, goal_overall_funded_formatted=None, goal_overall_funded_currency=None, goal_overall_left_formatted=None, goal_overall_left_currency=None)]), CategoryGroupWithCategories(id=UUID('b3a579ba-c92c-468f-aa77-ce13f7cfbe2c'), name='Moving Preparation', hidden=True, deleted=False, categories=[Category(id=UUID('01002297-2441-435d-a474-d572e18f8aa2'), category_group_id=UUID('b3a579ba-c92c-468f-aa77-ce13f7cfbe2c'), category_group_name='Moving Preparation', name='🏠 Security Deposit', hidden=True, original_category_group_id=None, note=None, budgeted=0, activity=0, balance=0, goal_type=None, goal_needs_whole_amount=None, goal_day=None, goal_cadence=None, goal_cadence_frequency=None, goal_creation_month=None, goal_target=0, goal_target_month=None, goal_target_date=None, goal_percentage_complete=None, goal_months_to_budget=None, goal_under_funded=None, goal_overall_funded=None, goal_overall_left=None, goal_snoozed_at=None, deleted=False, balance_formatted='฿0', balance_currency=0, activity_formatted='฿0', activity_currency=0, budgeted_formatted='฿0', budgeted_currency=0, goal_target_formatted='฿0', goal_target_currency=0, goal_under_funded_formatted=None, goal_under_funded_currency=None, goal_overall_funded_formatted=None, goal_overall_funded_currency=None, goal_overall_left_formatted=None, goal_overall_left_currency=None), Category(id=UUID('636d2cc3-4f9f-4f59-953b-c0b568d25cfc'), category_group_id=UUID('b3a579ba-c92c-468f-aa77-ce13f7cfbe2c'), category_group_name='Moving Preparation', name='📦 Customs Duty', hidden=True, original_category_group_id=None, note=None, budgeted=0, activity=0, balance=0, goal_type=None, goal_needs_whole_amount=None, goal_day=None, goal_cadence=None, goal_cadence_frequency=None, goal_creation_month=None, goal_target=0, goal_target_month=None, goal_target_date=None, goal_percentage_complete=None, goal_months_to_budget=None, goal_under_funded=None, goal_overall_funded=None, goal_overall_left=None, goal_snoozed_at=None, deleted=False, balance_formatted='฿0', balance_currency=0, activity_formatted='฿0', activity_currency=0, budgeted_formatted='฿0', budgeted_currency=0, goal_target_formatted='฿0', goal_target_currency=0, goal_under_funded_formatted=None, goal_under_funded_currency=None, goal_overall_funded_formatted=None, goal_overall_funded_currency=None, goal_overall_left_formatted=None, goal_overall_left_currency=None)]), CategoryGroupWithCategories(id=UUID('ab10bc27-7845-441a-b46b-80ec8bff9662'), name='Yusi Azizi', hidden=False, deleted=False, categories=[Category(id=UUID('95b960d0-6cfe-42df-9eb9-61dab68d4af4'), category_group_id=UUID('ab10bc27-7845-441a-b46b-80ec8bff9662'), category_group_name='Yusi Azizi', name='🏠 Rent', hidden=False, original_category_group_id=None, note=None, budgeted=23000000, activity=0, balance=23000000, goal_type='NEED', goal_needs_whole_amount=True, goal_day=6, goal_cadence=1, goal_cadence_frequency=1, goal_crea ...
# Category ID: cc1282d2-6772-4543-bc57-3060a9ae612d, Category Name: 🍽️ Dining out

# %%
with ynab.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = ynab.AccountsApi(api_client)
    plan_id = os.environ["YNAB_BUDGET_ID"] # str | The id of the plan. \"last-used\" can be used to specify the last used plan and \"default\" can be used if default plan selection is enabled (see: https://api.ynab.com/#oauth-default-plan).

    try:
        # Get all accounts
        api_response = api_instance.get_accounts(plan_id)
        print("The response of AccountsApi->get_accounts:\n")
        pprint(api_response)
    except Exception as e:
        print("Exception when calling AccountsApi->get_accounts: %s\n" % e)
# Out:
# The response of AccountsApi->get_accounts:
#
# AccountsResponse(data=AccountsResponseData(accounts=[Account(id=UUID('d16e629e-d84d-4cfa-8d8f-e7e561ebfe73'), name='BBL', type=<AccountType.CASH: 'cash'>, on_budget=True, closed=False, note=None, balance=145325000, cleared_balance=145325000, uncleared_balance=0, transfer_payee_id=UUID('0dcc985a-8e5a-4397-a96c-474b3070ac1f'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2026, 5, 4, 15, 46, 51, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='฿145325', balance_currency=145325, cleared_balance_formatted='฿145325', cleared_balance_currency=145325, uncleared_balance_formatted='฿0', uncleared_balance_currency=0), Account(id=UUID('e7059daa-3b58-431a-af92-3e7d2c44b6da'), name='Cash Yusi', type=<AccountType.CASH: 'cash'>, on_budget=True, closed=True, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('5c4bf9c6-5c2b-4cc2-8564-0e2a83961a6a'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2025, 6, 21, 9, 24, 22, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='฿0', balance_currency=0, cleared_balance_formatted='฿0', cleared_balance_currency=0, uncleared_balance_formatted='฿0', uncleared_balance_currency=0), Account(id=UUID('e5226ddc-dde0-4dc4-8eb3-c891e32faba2'), name='Mandiri Yusi', type=<AccountType.SAVINGS: 'savings'>, on_budget=True, closed=True, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('4f8401bf-249a-423d-8cb9-e5af4e8990b3'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2026, 4, 30, 9, 30, 17, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='฿0', balance_currency=0, cleared_balance_formatted='฿0', cleared_balance_currency=0, uncleared_balance_formatted='฿0', uncleared_balance_currency=0), Account(id=UUID('07c28d33-0a77-42de-a446-98a8410c523c'), name='Cash Azizi', type=<AccountType.CASH: 'cash'>, on_budget=True, closed=True, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('d6dc5b01-d355-4684-af65-5c28e723ed1f'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2025, 6, 18, 5, 37, 30, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='฿0', balance_currency=0, cleared_balance_formatted='฿0', cleared_balance_currency=0, uncleared_balance_formatted='฿0', uncleared_balance_currency=0), Account(id=UUID('dc2f17d4-8a3a-488f-8e4e-74149c627151'), name='Krungthai', type=<AccountType.CASH: 'cash'>, on_budget=True, closed=False, note=None, balance=56501000, cleared_balance=56501000, uncleared_balance=0, transfer_payee_id=UUID('818449e6-73ef-410c-9181-58dd61bc83e3'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2026, 5, 6, 10, 18, 22, tzinfo=TzInfo(0)), debt_original_balance=None, debt_interest_rates={}, debt_minimum_payments={}, debt_escrow_amounts={}, deleted=False, balance_formatted='฿56501', balance_currency=56501, cleared_balance_formatted='฿56501', cleared_balance_currency=56501, uncleared_balance_formatted='฿0', uncleared_balance_currency=0), Account(id=UUID('be193a84-3a0c-470f-a0cd-ec405602672d'), name='Uang Yusi', type=<AccountType.CASH: 'cash'>, on_budget=True, closed=True, note=None, balance=0, cleared_balance=0, uncleared_balance=0, transfer_payee_id=UUID('aa5792a5-ac1c-4d8f-bbce-7f68f66dfada'), direct_import_linked=False, direct_import_in_error=False, last_reconciled_at=datetime.datetime(2025, 7, 17, 10, 45, 51, tzinfo=TzInfo(0)), debt_original_balance=None, debt_inter ...

# %%
# !pip install rich
# Out:
# Collecting rich
#   Downloading rich-15.0.0-py3-none-any.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 917.1 kB/s eta 0:00:00a 0:00:01
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.10/site-packages (from rich) (2.20.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: mdurl, markdown-it-py, rich
# Successfully installed markdown-it-py-4.2.0 mdurl-0.1.2 rich-15.0.0
#
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from ynab.models.post_transactions_wrapper import PostTransactionsWrapper
from ynab.models.transaction_cleared_status import TransactionClearedStatus as TransactionClearedStatus
import rich

# Enter a context with an instance of the API client
with ynab.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = ynab.TransactionsApi(api_client)
    plan_id = os.environ["YNAB_BUDGET_ID"]
    data_dict = {
        "transaction": {
            "account_id": os.environ["YNAB_ACCOUNT_ID"],
            "date": "2026-05-10",
            "amount": -140000,
            "payee_id": "94760e7d-f213-4432-9d8e-5d014560d8b6",
            "category_id": "cc1282d2-6772-4543-bc57-3060a9ae612d",
            "cleared": TransactionClearedStatus.CLEARED,
            "approved": True,
        }
    }
    data = ynab.PostTransactionsWrapper().from_dict(data_dict) # PostTransactionsWrapper | The transaction or transactions to create.  To create a single transaction you can specify a value for the `transaction` object and to create multiple transactions you can specify an array of `transactions`.  It is expected that you will only provide a value for one of these objects.

    try:
        # Create a single transaction or multiple transactions
        api_response = api_instance.create_transaction(plan_id, data)
        print("The response of TransactionsApi->create_transaction:\n")
        pprint(api_response)
        rich.print(api_response.data.transaction)
    except Exception as e:
        print("Exception when calling TransactionsApi->create_transaction: %s\n" % e)
# Out:
# The response of TransactionsApi->create_transaction:
#
# SaveTransactionsResponse(data=SaveTransactionsResponseData(transaction_ids=['2b5e4957-2181-4fa9-a7cb-acbf1b4004b0'], transaction=TransactionDetail(id='2b5e4957-2181-4fa9-a7cb-acbf1b4004b0', var_date=datetime.date(2026, 5, 10), amount=-140000, memo=None, cleared=<TransactionClearedStatus.CLEARED: 'cleared'>, approved=True, flag_color=None, flag_name=None, account_id=UUID('d16e629e-d84d-4cfa-8d8f-e7e561ebfe73'), payee_id=UUID('94760e7d-f213-4432-9d8e-5d014560d8b6'), category_id=UUID('cc1282d2-6772-4543-bc57-3060a9ae612d'), transfer_account_id=None, transfer_transaction_id=None, matched_transaction_id=None, import_id=None, import_payee_name=None, import_payee_name_original=None, debt_transaction_type=None, deleted=False, amount_formatted='-฿140', amount_currency=-140, account_name='BBL', payee_name='Food Truck', category_name='🍽️ Dining out', subtransactions=[]), transactions=None, duplicate_import_ids=None, server_knowledge=7910))
# TransactionDetail(
#     id='2b5e4957-2181-4fa9-a7cb-acbf1b4004b0',
#     var_date=datetime.date(2026, 5, 10),
#     amount=-140000,
#     memo=None,
#     cleared=<TransactionClearedStatus.CLEARED: 'cleared'>,
#     approved=True,
#     flag_color=None,
#     flag_name=None,
#     account_id=UUID('d16e629e-d84d-4cfa-8d8f-e7e561ebfe73'),
#     payee_id=UUID('94760e7d-f213-4432-9d8e-5d014560d8b6'),
#     category_id=UUID('cc1282d2-6772-4543-bc57-3060a9ae612d'),
#     transfer_account_id=None,
#     transfer_transaction_id=None,
#     matched_transaction_id=None,
#     import_id=None,
#     import_payee_name=None,
#     import_payee_name_original=None,
#     debt_transaction_type=None,
#     deleted=False,
#     amount_formatted='-฿140',
#     amount_currency=-140,
#     account_name='BBL',
#     payee_name='Food Truck',
#     category_name='🍽️ Dining out',
#     subtransactions=[]
# )
